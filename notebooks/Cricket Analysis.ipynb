# %%
import pandas as pd

# %%
df = pd.read_csv("data/odi-batting.csv")

# %%
df.head()
# Out:
#        Country            Player  Runs   MatchDate Weekday  \
# 0  Afghanistan  Mohammad Shahzad   118  16-02-2010     Tue
# 1  Afghanistan  Mohammad Shahzad   110  01-09-2009     Tue
# 2  Afghanistan  Mohammad Shahzad   100  16-08-2010     Mon
# 3  Afghanistan  Mohammad Shahzad    82  10-07-2010     Sat
# 4  Afghanistan  Mohammad Shahzad    57  01-07-2010     Thu
#
#                   Ground       Versus  Balls
# 0     Sharjah CA Stadium       Canada    121
# 1             VRA Ground  Netherlands    111
# 2  Cambusdoon New Ground     Scotland     72
# 3            Hazelaarweg  Netherlands    108
# 4    Sportpark Westvliet       Canada     57

# %%
df.dtypes
# Out:
# Country      object
# Player       object
# Runs          int64
# MatchDate    object
# Weekday      object
# Ground       object
# Versus       object
# Balls         int64
# dtype: object

# %%
df["strike rate"] = round(df["Runs"]/df["Balls"])

# %%
df["strike rate"].describe()
# Out:
# count    50284.000000
# mean         0.738247
# std          0.556688
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          6.000000
# Name: strike rate, dtype: float64

# %%
df['strike rate'].value_counts()
# Out:
# 1.0    32270
# 0.0    15726
# 2.0     2091
# 3.0      128
# 4.0       63
# 6.0        4
# 5.0        2
# Name: strike rate, dtype: int64

# %%
df[df['strike rate'] == 6.0]
# Out:
#         Country                   Player  Runs   MatchDate Weekday  \
# 18203     India           Yusuf K Pathan     6  23-11-2008     Sun
# 18988     India  Bapu K Venkatesh Prasad     6  07-10-2000     Sat
# 29715  Pakistan              Wasim Akram     6  01-11-1989     Wed
# 32185  Pakistan              Aaqib Javed     6  10-01-1995     Tue
#
#                       Ground        Versus  Balls  strike rate
# 18203  M.Chinnaswamy Stadium       England      1          6.0
# 18988   Gymkhana Club Ground     Australia      1          6.0
# 29715           Eden Gardens   West Indies      1          6.0
# 32185               Newlands  South Africa      1          6.0

# %%
dfIndia = df[df["Country"] == "India"]

# %%
dfIndia.head()
# Out:
#       Country              Player  Runs   MatchDate Weekday  \
# 13601   India  Sachin R Tendulkar   200  24-02-2010     Wed
# 13602   India  Sachin R Tendulkar   186  08-11-1999     Mon
# 13603   India  Sachin R Tendulkar   175  05-11-2009     Thu
# 13604   India  Sachin R Tendulkar   163  08-03-2009     Sun
# 13605   India  Sachin R Tendulkar   152  23-02-2003     Sun
#
#                                    Ground        Versus  Balls  strike rate
# 13601          Captain Roop Singh Stadium  South Africa    147          1.0
# 13602         Lal Bahadur Shastri Stadium   New Zealand    150          1.0
# 13603  Rajiv Gandhi International Stadium     Australia    141          1.0
# 13604                         AMI Stadium   New Zealand    133          1.0
# 13605                           City Oval       Namibia    151          1.0

# %%
dfIndia.Runs.describe()
# Out:
# count    6049.000000
# mean       26.319722
# std        28.055340
# min         1.000000
# 25%         6.000000
# 50%        16.000000
# 75%        38.000000
# max       200.000000
# Name: Runs, dtype: float64

# %%
dfIndia[dfIndia["Runs"]==200]
# Out:
#       Country              Player  Runs   MatchDate Weekday  \
# 13601   India  Sachin R Tendulkar   200  24-02-2010     Wed
#
#                            Ground        Versus  Balls  strike rate
# 13601  Captain Roop Singh Stadium  South Africa    147          1.0

# %%
dfIndia.dtypes
# Out:
# Country         object
# Player          object
# Runs             int64
# MatchDate       object
# Weekday         object
# Ground          object
# Versus          object
# Balls            int64
# strike rate    float64
# dtype: object

# %%
dfIndia["Year"] = df.MatchDate.apply(lambda x: 0 if x=="0" else x.split("-")[-1])
# Out:
# <ipython-input-32-6741c6ce6046>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfIndia["Year"] = df.MatchDate.apply(lambda x: 0 if x=="0" else x.split("-")[-1])

# %%
dfIndia
# Out:
#       Country              Player  Runs   MatchDate Weekday  \
# 13601   India  Sachin R Tendulkar   200  24-02-2010     Wed
# 13602   India  Sachin R Tendulkar   186  08-11-1999     Mon
# 13603   India  Sachin R Tendulkar   175  05-11-2009     Thu
# 13604   India  Sachin R Tendulkar   163  08-03-2009     Sun
# 13605   India  Sachin R Tendulkar   152  23-02-2003     Sun
# ...       ...                 ...   ...         ...     ...
# 19645   India     Rajinder S Ghai     1  26-01-1986     Sun
# 19646   India     Nandlal S Yadav     1  09-02-1986     Sun
# 19647   India        Naman V Ojha     1  05-06-2010     Sat
# 19648   India        Sudeep Tyagi     1  27-02-2010     Sat
# 19649   India        Yograj Singh     1  14-02-1981     Sat
#
#                                    Ground        Versus  Balls  strike rate  \
# 13601          Captain Roop Singh Stadium  South Africa    147          1.0
# 13602         Lal Bahadur Shastri Stadium   New Zealand    150          1.0
# ...

# %%
dfIndia.Year = dfIndia.Year.astype("int32")
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
dfIndia2 = dfIndia[dfIndia["Year"] < 2000]

# %%
dfIndia2['Balls'].describe()
# Out:
# count    3258.000000
# mean       34.553714
# std        31.938396
# min         1.000000
# 25%        10.000000
# 50%        24.000000
# 75%        50.000000
# max       174.000000
# Name: Balls, dtype: float64

# %%
dfIndia2[dfIndia2['Balls'] == 174]
# Out:
#       Country            Player  Runs   MatchDate Weekday  Ground   Versus  \
# 16622   India  Sunil M Gavaskar    36  07-06-1975     Sat  Lord's  England
#
#        Balls  strike rate  Year
# 16622    174          0.0  1975

# %%
order = pd.read_csv('https://query.data.world/s/3hIAtsCE7vYkPEL-O5DyWJAeS5Af-7')
order['Order_Date'] = pd.to_datetime(order['Order_Date'])

# %%
order
# Out:
#       Order_ID Order_Date Order_Priority    Ord_id
# 0            3 2010-10-13            LOW     Ord_1
# 1          293 2012-01-10           HIGH     Ord_2
# 2          483 2011-10-07           HIGH     Ord_3
# 3          515 2010-08-28  NOT SPECIFIED     Ord_4
# 4          613 2011-06-17           HIGH     Ord_5
# ...        ...        ...            ...       ...
# 5501     47360 2010-08-10  NOT SPECIFIED  Ord_5502
# 5502     52706 2012-09-07            LOW  Ord_5503
# 5503     54279 2011-07-30           HIGH  Ord_5504
# 5504     55558 2010-09-08         MEDIUM  Ord_5505
# 5505     56581 2009-08-02           HIGH  Ord_5506
#
# [5506 rows x 4 columns]

# %%
order["day"] = order.Order_Date.apply(lambda x: 0 if x=="0" else x.day)

# %%
order
# Out:
#       Order_ID Order_Date Order_Priority    Ord_id  day
# 0            3 2010-10-13            LOW     Ord_1   13
# 1          293 2012-01-10           HIGH     Ord_2   10
# 2          483 2011-10-07           HIGH     Ord_3    7
# 3          515 2010-08-28  NOT SPECIFIED     Ord_4   28
# 4          613 2011-06-17           HIGH     Ord_5   17
# ...        ...        ...            ...       ...  ...
# 5501     47360 2010-08-10  NOT SPECIFIED  Ord_5502   10
# 5502     52706 2012-09-07            LOW  Ord_5503    7
# 5503     54279 2011-07-30           HIGH  Ord_5504   30
# 5504     55558 2010-09-08         MEDIUM  Ord_5505    8
# 5505     56581 2009-08-02           HIGH  Ord_5506    2
#
# [5506 rows x 5 columns]
